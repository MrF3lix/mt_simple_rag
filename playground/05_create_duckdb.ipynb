# %%
import duckdb
import pandas as pd

# %%
SOURCE = '../data/kilt_wiki_small.duckdb'
WIKI = '../data/kilt_wiki_small.jsonl'
PARAGRAPHS = '../data/kilt_wiki_small_paragraphs.jsonl'

# %%
df = pd.read_json(WIKI, orient='records', lines=True)

df_wiki = df[['kilt_id', 'wikipedia_id', 'wikipedia_title', 'text', 'categories']]
df_wiki.head(1)
# Out:
#    kilt_id  wikipedia_id wikipedia_title  \
# 0      339           339        Ayn Rand
#
#                                                 text  \
# 0  {'paragraph': ['Ayn Rand
# ', 'Ayn Rand (; born ...
#
#                                           categories
# 0  American women novelists,American abortion-rig...

# %%
df_p = pd.read_json(PARAGRAPHS, orient='records', lines=True)

df_p_small = df_p[['kilt_id', 'paragraph_id', 'paragraph']]
df_p_small.head(1)
# Out:
#    kilt_id  paragraph_id                           paragraph
# 0    76383             0  The Ten Commandments (1956 film)\n

# %%
con = duckdb.connect(SOURCE)

# %%
con.execute("SELECT count(*) FROM paragraph;").fetchall()[0][0]
# Out:
# 146644

# %%
con.sql("DROP TABLE IF EXISTS wiki")
con.sql('CREATE TABLE wiki AS SELECT * FROM df_wiki')
con.sql("INSERT INTO wiki SELECT * FROM df_wiki")

con.sql("DROP TABLE IF EXISTS paragraph")
con.sql("CREATE TABLE paragraph (wikipedia_id VARCHAR, wikipedia_title VARCHAR, id BIGINT, index INTEGER, text VARCHAR);")
con.sql("CREATE SEQUENCE paragraph_id START 1;")

con.execute("""
INSERT INTO paragraph
SELECT
    wikipedia_id,
    wikipedia_title,
    nextval('paragraph_id') as id,
    idx AS index,
    paragraph AS text
FROM wiki, UNNEST(text.paragraph) WITH ORDINALITY AS t(paragraph, idx);
""")

# con.sql('CREATE TABLE paragraph AS SELECT * FROM df_p_small')
# con.sql("INSERT INTO paragraph SELECT * FROM df_p_small")

# %%
con.execute("SHOW ALL TABLES").df()
# Out:
#           database schema       name  \
# 0  kilt_wiki_small   main  paragraph
# 1  kilt_wiki_small   main       wiki
#
#                                         column_names  \
# 0   [wikipedia_id, wikipedia_title, id, index, text]
# 1  [kilt_id, wikipedia_id, wikipedia_title, text,...
#
#                                         column_types  temporary
# 0       [VARCHAR, VARCHAR, BIGINT, INTEGER, VARCHAR]      False
# 1  [BIGINT, BIGINT, VARCHAR, STRUCT(paragraph VAR...      False

# %%
con.execute("SELECT * FROM wiki LIMIT 5").df()
# Out:
#    kilt_id  wikipedia_id    wikipedia_title  \
# 0      339           339           Ayn Rand
# 1      358           358            Algeria
# 2    20134         20134  Minnesota Vikings
# 3   420438        420438       Steven Tyler
# 4   269859        269859   A Perfect Circle
#
#                                                 text  \
# 0  {'paragraph': ['Ayn Rand
# ', 'Ayn Rand (; born ...
# 1  {'paragraph': ['Algeria
# ', 'Algeria ( ; , ; ),...
# 2  {'paragraph': ['Minnesota Vikings
# ', 'The Minn...
# 3  {'paragraph': ['Steven Tyler
# ', 'Steven Tyler ...
# 4  {'paragraph': ['A Perfect Circle
# ', 'A Perfect...
#
#                                           categories
# 0  American women novelists,American abortion-rig...
# 1  Arab republics,Algeria,States and territories ...
# 2  Minnesota Vikings,American football teams esta...
# 3  1948 births,Songwriters from Massachusetts,20t...
# 4  Alternative metal supergroups,Musical quintets...

# %%
con.execute("SELECT * FROM paragraph LIMIT 5").df()
# Out:
#   wikipedia_id    wikipedia_title  id  index  \
# 0          339           Ayn Rand   1    101
# 1          358            Algeria   2    197
# 2        20134  Minnesota Vikings   3    262
# 3       420438       Steven Tyler   4     81
# 4       269859   A Perfect Circle   5     54
#
#                                                 text
# 0  BULLET::::- "Writings of Ayn Rand" – from C-SP...
# 1  BULLET::::- EU Neighbourhood Info Centre: Alge...
# 2  BULLET::::- List of Minnesota Vikings broadcas...
# 3  BULLET::::- 2011 – "Outstanding Performer In A...
# 4            BULLET::::- "Eat the Elephant" (2018)\n

# %%
result = con.execute("SELECT * FROM paragraph LIMIT 5 OFFSET 5").df()
result
# Out:
#   wikipedia_id wikipedia_title  id  index  \
# 0          595    Andre Agassi   6    137
# 1       206724   Anne Bancroft   7     39
# 2       206705   Colin Farrell   8     60
# 3     23861381        Bradford   9    207
# 4     21909903   Catching Fire  10     26
#
#                                                 text
# 0  BULLET::::- Agassi's Tennis Hall of Fame Induc...
# 1  BULLET::::- Anne Bancroft at the University of...
# 2  BULLET::::- "New Yorker" caricatures of Farrel...
# 3             BULLET::::- Sunrise and sunset times\n
# 4          BULLET::::- Scholastic official website\n
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
BATCH_ROWS = 512
cursor = con.execute("SELECT * FROM paragraph")

rows = cursor.fetchmany(BATCH_ROWS)
rows
# Out:
# [('339',
#   'Ayn Rand',
#   101,
#   'BULLET::::- "Writings of Ayn Rand" – from C-SPAN\'s ""\n'),
#  ('358',
#   'Algeria',
#   197,
#   'BULLET::::- EU Neighbourhood Info Centre: Algeria\n'),
#  ('20134',
#   'Minnesota Vikings',
#   262,
#   'BULLET::::- List of Minnesota Vikings broadcasters\n'),
#  ('420438',
#   'Steven Tyler',
#   81,
#   'BULLET::::- 2011 – "Outstanding Performer In An Animated Program" – For playing "The Mad Hatter" on The Wonder Pets: Adventures in Wonderland (nominated)\n'),
#  ('269859', 'A Perfect Circle', 54, 'BULLET::::- "Eat the Elephant" (2018)\n'),
#  ('595',
#   'Andre Agassi',
#   137,
#   "BULLET::::- Agassi's Tennis Hall of Fame Induction for Steffi Graf\n"),
#  ('206724',
#   'Anne Bancroft',
#   39,
#   "BULLET::::- Anne Bancroft at the University of Wisconsin's Actors Studio audio collection\n"),
#  ('206705',
#   'Colin Farrell',
#   60,
#   'BULLET::::- "New Yorker" caricatures of Farrell and Brendan Gleeson in "In Bruges"\n'),
#  ('23861381', 'Bradford', 207, 'BULLET::::- Sunrise and sunset times\n'),
#  ('21909903',
#   'Catching Fire',
#   26,
#   'BULLET::::- Scholastic official website\n'),
#  ('717', 'Alberta', 191, 'BULLET::::- Alberta Encyclopedia\n'),
#  ('737', 'Afghanistan', 199, 'BULLET::::- Research Guide to Afghanistan\n'),
#  ('5649829',
#   'Winter Passing',
#   19,
#   'Roger Ebert rated the film at 3.5 out of 4 stars, lauding how the balances sadness, loneliness, humor and affection. He stated: "This is the kind of movie routinely dismissed as too slow and quiet by those who don\'t know it is more exciting to listen than to hear."\n'),
#  ('74903', 'Horseshoe Falls', 10, 'BULLET::::- Iroquois mythology\n'),
#  ('421292',
#   'Grace Jones',
#   64,
#   'Jones\' real last name is often referred to as "Mendoza", which is actually a name she used in her 20s to fool her parents.\n'),
#  ('18959138',
#   'Antarctica',
#   164,
#   'BULLET::::- Video: The Bedrock Beneath Antarctica\n'),
#  ('842', 'Aegean Sea', 83, 'BULLET::::- Thracian Sea\n'),
#  ('848', 'Audi', 179, 'BULLET::::- Horch\n'),
#  ('844', 'Amsterdam', 204, 'BULLET::::- Free English guided walking tour\n'),
#  ('856', 'Apple Inc.', 284, 'BULLET::::- Pixar\n'),
#  ('18965892',
#   'Lymelife',
#   27,
#   'The film premiered at the 2008 Toronto International Film Festival and won the International Federation of Film Critics award (FIPRESCI). The film received a 63% approval rating on Rotten Tomatoes based on 109 reviews; the average rating is 6.1/10. The consensus states: ""Lymelife" features sharp performances, but the story lacks the emotional depth or focus worthy of its talented cast."\n'),
#  ('44219', 'Mel Gibson', 162, 'BULLET::::- Mel Gibson at AllMovie\n'),
#  ('2804704',
#   'Gone with the Wind (film)',
#   134,
#   'BULLET::::- "Gone with the Wind" article series at "The Atlantic"\n'),
#  ('208400', 'Neal Schon', 105, 'BULLET::::- Neal Schon Biography\n'),
#  ('18060198',
#   'Shonen Jump (magazine)',
#   34,
#   'BULLET::::- List of manga magazines published outside of Japan\n'),
#  ('34604303',
#   'Quartet (2012 film)',
#   49,
#   'Lisa Schwarzbaum of "Entertainment Weekly" gave the movie a B, writing,This lulling inspirational fantasy/comedy in the key of "The Best Exotic Marigold Hotel" offers aging, cultured Englishfolk (and one randy Scot, played by Billy Connolly) living out their golden years in a beautifully maintained residence for retired musicians. Every vista suggests that this gracious oldies\' home is situated down the road from Downton Abbey, and every scene insists that real physical or mental infirmity belongs in some other picture.\n'),
#  ('2025815',
#   'Louise Simonson',
#   105,
#   'BULLET::::- Louise Simonson at the Unofficial Handbook of Marvel Comics Creators\n'),
#  ('23882849',
#   'Taylor Schilling',
#   13,
#   'BULLET::::- LGBTQ culture in New York City\n'),
#  ('1218644', 'Jordan Knight', 39, 'BULLET::::- Trans Continental Records\n'),
#  ('158889',
#   'George Clooney',
#   69,
#   'Throughout his career, Clooney has won two Academy Awards, one for Best Supporting Actor for his role in "Syriana" and one for Best Picture as one of the producers for "Argo", as well as a BAFTA and a Golden Globe. For his role in "The Descendants", he won a Golden Globe Award and was nominated for an Academy Award, BAFTA Award, Satellite Award, and two Screen Actors Guild Awards: Best Lead Actor and Best Cast. On January 11, 2015, Clooney was awarded the Golden Globe Cecil B. DeMille Lifetime Achievement Award.\n'),
#  ('209066',
#   'Reba McEntire',
#   117,
#   'BULLET::::- Reba McEntire Profile on Country Music Television\n'),
#  ('22941812',
#   'Furia (film)',
#   11,
#   'BULLET::::- Étienne Chicot as Quicailler\n'),
#  ('75912', 'Time Lord', 102, 'BULLET::::- Time War (Doctor Who)\n'),
#  ('76033',
#   'The Great Gatsby',
#   105,
#   'BULLET::::- An Index to "The Great Gatsby"\n'),
#  ('52281037', 'Inhumans (TV series)', 89, 'BULLET::::- General references\n'),
#  ('756494',
#   'Tanya Roberts',
#   20,
#   'Roberts was married to husband Barry Roberts from 1974 until his death in 2006. They had no children. Roberts resides in Hollywood Hills, California.\n'),
#  ('422524',
#   'National Library of India',
#   35,
#   'BULLET::::- National Library of India\n'),
#  ('21003892',
#   'Lee Min-ho (actor)',
#   46,
#   'BULLET::::- Official Japanese website\n'),
#  ('346200',
#   'Kurt Angle',
#   210,
#   'BULLET::::- Kurt Angle at The National Wrestling Hall of Fame website\n'),
#  ('39383953',
#   'In the Heart of the Sea (film)',
#   57,
#   'BULLET::::- Survival film, about the film genre, with a list of related films\n'),
#  ('38242002',
#   'Until Dawn',
#   36,
#   'Sony announced a non-canonical spin-off titled "" at Paris Games Week 2015; the company described it as an arcade shooter. The new game\'s development began halfway through "Until Dawn"\'s development. "Until Dawn: Rush of Blood" was released on the PlayStation VR on 13 October 2016. In June 2017, "The Inpatient", a prequel to "Until Dawn" that is set in the Blackwood Sanatorium sixty years before the original, was announced.\n'),
#  ('1219461',
#   'J. Howard Marshall',
#   29,
#   'BULLET::::- Again, Hot Oil from Time Magazine, 1938\n'),
#  ('159268',
#   'River Phoenix',
#   66,
#   'BULLET::::- Holmstrom, John. "The Moving Picture Boy: An International Encyclopaedia from 1895 to 1995". Norwich, Michael Russell, 1996, p.\xa0380-381.\n'),
#  ('37026799',
#   'Unapologetic',
#   171,
#   'BULLET::::- Promotional website for the album\n'),
#  ('76383',
#   'The Ten Commandments (1956 film)',
#   128,
#   'BULLET::::- Costume design drawings for "The Ten Commandments", Margaret Herrick Library, Academy of Motion Picture Arts and Sciences\n'),
#  ('625105',
#   'David Koepp',
#   15,
#   "Koepp was born in Pewaukee, Wisconsin, to a family therapist mother, and Donald Koepp, who owned a billboard company. While attending Kettle Moraine High School in Wales, Wisconsin, he worked evenings and weekends at the McDonald's restaurant in Delafield. He received his bachelor's in film from UCLA. He has a wife, Melissa, and four children.\n"),
#  ('347105', 'Mother Teresa', 139, 'BULLET::::- Mother Teresa contrasts:\n'),
#  ('45230258',
#   'Beauty and the Beast (2017 film)',
#   78,
#   'On March 21, 2017, Sean Bailey said that Walt Disney Pictures will "explore possible [live-action] spinoff and prequel scenarios" for animated and live-action Disney films, including "Beauty and the Beast". On April 22, 2017, Dan Stevens expressed interest in reprisng his role as the Beast in a potential prequel. On January 9, 2018, Emma Watson also expressed interest in reprising her role as Belle in a potential sequel.\n'),
#  ('44469',
#   'Pluto',
#   112,
#   'BULLET::::- Interactive 3D visualisation of the Plutonian system\n'),
#  ('44475',
#   'Uranus',
#   105,
#   'BULLET::::- Interactive 3D visualisation of the Uranian system\n'),
#  ('35896442',
#   'Destiny (video game)',
#   100,
#   'BULLET::::- "Destiny" at Bungie\n'),
#  ('18998750',
#   'Reuters',
#   72,
#   'BULLET::::- Thomson Reuters Foundation – philanthropic foundation\n'),
#  ('21019',
#   'Michelangelo',
#   119,
#   'BULLET::::- "Michelangelo: The Man and the Myth"\n'),
#  ('76972',
#   'Denmark',
#   194,
#   'BULLET::::- Vifanord.de – library of scientific information on the Nordic and Baltic countries.\n'),
#  ('1061378',
#   'James Marsden',
#   28,
#   'BULLET::::- Interview on "The Notebook" and "X-Men 3"\n'),
#  ('159599', 'Ben Affleck', 85, 'BULLET::::- Matt Damon\n'),
#  ('33509716',
#   '21 Jump Street (film)',
#   79,
#   'A female-driven "21 Jump Street" film is being developed. In December 2016, Rodney Rothman was announced as the director and screenwriter for the film. Rothman returns to the franchise after co-writing "22 Jump Street". In December 2018, Tiffany Haddish was confirmed to lead the film and Awkwafina is in talks.\n'),
#  ('1221476',
#   'Chris Hemsworth',
#   20,
#   'Hemsworth began dating Spanish actress Elsa Pataky in early 2010 after meeting through their mutual representatives. They wed in December 2010. They have three children: a daughter born in May 2012, and twin sons born in March 2014. In 2015, Hemsworth and his family moved from Los Angeles to Byron Bay in his native Australia.\n'),
#  ('8107008',
#   'Pablo Fenjves',
#   7,
#   'Fenjves collaborated with O.J. Simpson to ghostwrite "If I Did It", an account of the O. J. Simpson murder case. The book was pulled by the publisher just weeks before its release date, but it was subsequently revived by Fred Goldman, father of murder victim Ron Goldman, and spent five weeks on "The New York Times" Best Seller list. Fenjves had a personal connection to the Simpson case: Fenjves lived a few doors down from the Brentwood murder scene, and had testified against Simpson regarding the time at which he heard Nicole Simpson\'s dog barking.\n'),
#  ('22965242',
#   'Romelu Lukaku',
#   80,
#   'BULLET::::- Profile at the Manchester United F.C. website\n'),
#  ('77390',
#   'Natalie Wood',
#   65,
#   'BULLET::::- Interview with Natalie Wood’s daughter, Natasha Gregson Wagner. Accessed November 17, 2016.\n'),
#  ('77520',
#   'Anaheim, California',
#   202,
#   'BULLET::::- Anaheim, California on the C-SPAN Cities Tour website\n'),
#  ('44735', 'Sharon Tate', 80, 'BULLET::::- Famously Dead\n'),
#  ('46883270',
#   'The Girl on the Train (2016 film)',
#   52,
#   '"Chicago Sun-Times\' " Richard Roeper gave 2 stars out 4, and said that the film is "shiny trash that begins with promise but quickly gets tripped up by its own screenplay and grows increasingly ludicrous and melodramatic, to the point where I was barely able to suppress a chuckle at some of the final scenes". Christy Lemire of "RogerEbert.com" gave 1½ stars out of 4, and described the film as, "a flat and suspense-free tale of pretty people in peril".\n'),
#  ('10536433',
#   'License to Wed',
#   31,
#   'The film grossed $10,422,258 in its opening weekend opening at #4 at the U.S. Box Office behind "Live Free or Die Hard", "Ratatouille", and "Transformers", which opened at the top spot. As of November 11, 2007, "License to Wed" had grossed $43.8 million domestically and $70.2 million worldwide, both career highs for Mandy Moore as a lead actress, and a box office success after a $35 million reported budget.\n'),
#  ('210998',
#   'The Matrix Revolutions',
#   37,
#   'BULLET::::- "The Matrix Revolution" October 27, 2000 draft script by Andy & Larry Wachowski\n'),
#  ('211087',
#   'Inspectah Deck',
#   29,
#   'BULLET::::- "Czarface Meets Ghostface" (2019)\n'),
#  ('44849', 'Brad Pitt', 56, 'BULLET::::- Brad Pitt at Huffington Post\n'),
#  ('517195', 'Alan Ladd', 149, 'BULLET::::- Alan Ladd at Virtual History\n'),
#  ('2038117',
#   'Naturi Naughton',
#   28,
#   'BULLET::::- Naturi Naughton: The Notorious Interview with Kam Williams\n'),
#  ('5174671', '30 Rock', 116, 'BULLET::::- Fully Quoted Episodes\n'),
#  ('160481', 'Lisa Bonet', 20, 'BULLET::::- Music video director\n'),
#  ('32427039',
#   'Oz the Great and Powerful',
#   68,
#   'BULLET::::- Adaptations of "The Wizard of Oz"\n'),
#  ('21247',
#   'Neil Armstrong',
#   120,
#   'BULLET::::- Neil Armstrong collected news and commentary. "The New York Times".\n'),
#  ('2822968',
#   'R. Madhavan',
#   55,
#   'BULLET::::- Critics\' Best Tamil Actor for "Vikram Vedha".\n'),
#  ('1623',
#   'Andrew Jackson',
#   180,
#   'BULLET::::- "The 1828 Campaign of Andrew Jackson and the Growth of Party Politics", lesson plan at the National Endowment for the Humanities\n'),
#  ('45242',
#   'Reds (film)',
#   84,
#   'BULLET::::- "Film on a Revolution Was a Revolution Itself"; A.O. Scott, "The New York Times" (October 4, 2006)\n'),
#  ('1067262', 'Filmfare', 21, 'BULLET::::- List of magazines in India\n'),
#  ('78242',
#   'The Sopranos',
#   137,
#   'The first four seasons of "The Sopranos" were released on VHS in five-volume box sets, which lacked bonus features. All six seasons were released as DVD box sets, with the final season released in two parts; two different versions of the complete series were also released. The sixth season (both parts 1 and 2) was also released on Blu-ray Disc and HD DVD in 2006 and 2007, respectively. The first season was released on Blu-ray in 2009. A complete series box set was released on Blu-ray on November 4, 2014.\n'),
#  ('212187',
#   'John Mayer',
#   125,
#   'BULLET::::- Edwards, G. (2006). "Is Tiny Dancer Really Elton\'s Little John?" New York: Crown Publishing Group. .\n'),
#  ('276341',
#   'Anna Paquin',
#   32,
#   'BULLET::::- List of New Zealand Academy Award winners and nominees\n'),
#  ('21383', 'Nigeria', 244, 'BULLET::::- Outline of Nigeria\n'),
#  ('160985',
#   'Emma Thompson',
#   66,
#   'Thompson was appointed Dame Commander of the Order of the British Empire (DBE) in the 2018 Birthday Honours for services to drama.\n'),
#  ('45324',
#   'Hogwarts',
#   106,
#   "BULLET::::- The Marauder's Map from the Warner Bros website, harrypotter.warnerbros.co.uk\n"),
#  ('518700', 'Jennifer Hudson', 58, 'BULLET::::- "JHUD" (2014)\n'),
#  ('21504', 'Nicole Kidman', 66, "BULLET::::- Nicole Kidman's charity work\n"),
#  ('21566',
#   'Noam Chomsky',
#   118,
#   'BULLET::::- Demonstration at Faneuil Hall to protest indictment of the Berrigan brothers: Noam Chomsky speaking with Vern Countryman and George Wald at left and Howard Zinn at the far right, January 1971 (Photo: Jeff Albertson Photograph Collection (PH 57)), Special Collections and University Archives, Library of the University of Massachusetts: Amherst.\n'),
#  ('519607',
#   'Kathy Bates',
#   37,
#   'BULLET::::- List of actors with two or more Academy Award nominations in acting categories\n'),
#  ('350841',
#   'Emilio Estevez',
#   62,
#   '! colspan="3" style="background: #DAA520;" | Bronze Wrangler Awards\n'),
#  ('161356', 'Journey (band)', 70, 'BULLET::::- The Journey Zone\n'),
#  ('78969',
#   'Pixar',
#   89,
#   'BULLET::::- List of the 40 founding employees of Pixar\n'),
#  ('277011', 'Tom Felton', 38, 'BULLET::::- Six String Productions\n'),
#  ('79289',
#   'German Shepherd',
#   94,
#   'BULLET::::- Verein für Deutsche Schäferhunde e.V.—The original registrar of the German Shepherd\n'),
#  ('28005401',
#   'The Catalyst',
#   23,
#   'All songs written and composed by Linkin Park.\n'),
#  ('23011287',
#   'Following',
#   41,
#   'BULLET::::- "Following: Nolan Begins" an essay by Scott Foundas at the Criterion Collection\n'),
#  ('21757',
#   'New York Giants',
#   126,
#   'BULLET::::- List of New York Giants seasons\n'),
#  ('213270',
#   'Back to the Future Part II',
#   64,
#   'BULLET::::- List of films featuring drones\n'),
#  ('213394',
#   'Tom Morello',
#   189,
#   'BULLET::::- "High Hopes In South Africa" (2014) ... Himself\n'),
#  ('2377',
#   'Andhra Pradesh',
#   162,
#   'BULLET::::- Andhra Pradesh "Encyclopædia Britannica" entry\n'),
#  ('21939',
#   'National Security Agency',
#   391,
#   'BULLET::::- National Security Agency (NSA) Archive on the Internet Archive\n'),
#  ('4689264', 'Australia', 138, 'BULLET::::- Tourism Australia\n'),
#  ('277721',
#   'Kate Beckinsale',
#   57,
#   'The British Heart Foundation has been Beckinsale\'s charity of choice "ever since [she] was six years old" when her father, who had a congenital heart defect, died of a massive heart attack. She has also donated film memorabilia to the Epidermolysis Bullosa Medical Research Foundation, MediCinema, Habitat For Humanity and the Entertainment Industry Foundation. In 2008 she hosted the 4th Annual Pink Party to raise funds for the Women\'s Cancer Research Institute at Cedars-Sinai Medical Center and organised a screening of "All About Eve" for FilmAid International. In 2012 Beckinsale joined Nestlé\'s Share the Joy of Reading Program to raise awareness about the importance of people\'s literacy.\n'),
#  ('1230157', 'Alandi', 63, 'BULLET::::- http://santeknath.org/karya.html\n'),
#  ('44046048', 'Joey Graceffa', 39, 'BULLET::::- Official website\n'),
#  ('162177', 'Rogue (comics)', 145, 'BULLET::::- Rogue at Comic Vine\n'),
#  ('21980',
#   'Newfoundland and Labrador',
#   162,
#   'BULLET::::- Official Tourism Website\n'),
#  ('40600541', 'Laurie Hernandez', 65, 'BULLET::::- List of Puerto Ricans\n'),
#  ('214233',
#   'Nina Simone',
#   78,
#   'BULLET::::- The Amazing Nina Simone: A Documentary Film\n'),
#  ('278119',
#   'Charlie Sheen',
#   71,
#   'BULLET::::- List of awards and nominations received by Charlie Sheen\n'),
#  ('25854460',
#   'Red (2010 film)',
#   44,
#   'The film\'s financial success surpassed producer Lorenzo di Bonaventura\'s expectations. In October 2011, Summit Entertainment officially announced that "Red 2" would be released on August 2, 2013, with Jon and Erich Hoeber rehired to write the screenplay. In March 2013, the film\'s release date was moved from August 2, 2013 to July 19, 2013. The sequel fared worse than its predecessor both critically and financially. The film received mixed reviews from critics and grossed $148.1 million worldwide.\n'),
#  ('766887',
#   'Bring It On (film)',
#   65,
#   'BULLET::::- "Bring It On" filming locations\n'),
#  ('19043935', 'Lisa Marie Presley', 71, 'BULLET::::- Storm & Grace Tour\n'),
#  ('922702',
#   'Andrew Wood (singer)',
#   32,
#   'On July 7, 2015 at a NYC show Slipknot and Stone Sour front man Corey Taylor performed "Chloe Dancer."\n'),
#  ('22349',
#   'Odyssey',
#   130,
#   'BULLET::::- "The Odyssey" - Annotated text and analyses aligned to Common Core Standards\n'),
#  ('80335',
#   'Helena Bonham Carter',
#   53,
#   'BULLET::::- Helena Bonham Carter at Emmys.com\n'),
#  ('429833',
#   'Peyton Manning',
#   222,
#   'BULLET::::- Indianapolis Colts biography\n'),
#  ('1233754', 'Tom Welling', 32, 'BULLET::::- Verified Facebook Page\n'),
#  ('5200967',
#   'Cindy McCain',
#   60,
#   'Once it became time, McCain reportedly indicated that she was not interested in being appointed to her husband\'s Senate seat, as personal participation in electoral politics did not appeal to her. As one former aide stated, "It is a mistake to understand the McCains as a political family. They\'re a military family first and a political family second." Nonetheless she still wielded some influence in terms of who would be picked. On September 4, Ducey – who had by this time easily won the Republican primary – appointed former Arizona senator Jon Kyl to the seat, in a choice that was satisfactory to all factions within the state Republican party. McCain referred to Kyl as "a dear friend of mine and John\'s. It\'s a great tribute to John that he is prepared to go back into public service to help the state of Arizona."\n'),
#  ('1428952',
#   'Performance (film)',
#   65,
#   'BULLET::::- "Performance" by Colin MacCabe (book)\n'),
#  ('41719050',
#   'Born Naked',
#   9,
#   'BULLET::::- signifies original producer in addition to remix engineer and additional producer\n'),
#  ('2539269',
#   'Marion Cotillard',
#   84,
#   'BULLET::::- List of French Academy Award winners and nominees\n'),
#  ('2539671',
#   'Ten Commandments',
#   150,
#   'BULLET::::- Ten Commandments: "Ex. 20" version (text, mp3), "Deut. 5" version (text, mp3) in The Hebrew Bible in English by Jewish Publication Society, 1917 ed.\n'),
#  ('2844938', 'Mark Zuckerberg', 114, 'BULLET::::- Mark Zuckerberg - Forbes\n'),
#  ('80696', 'Cher', 217, 'Notes\n'),
#  ('5208783',
#   'Dhool',
#   43,
#   'BULLET::::- Filmfare Award for Best Comedian – Tamil - Vivek\n'),
#  ('1620586',
#   'Avatar: The Last Airbender',
#   51,
#   'Critics also praised "Avatar: The Last Airbender" character development, art, animation, and choreography; Eric Amaya enjoyed the expressive animation that complements the writing. According to Amaya, the elements were influenced by Hayao Miyazaki. Todd Douglass, Jr. called the character development interesting, while Nicole Clark wrote that the show "managed to do what so few shows even today have: assemble a cast of characters that depicts the world as it is, with a range of identities and experiences." Jenifer Rosenburg praised the series\' portrayal of females as "strong, responsible, [and] intelligent". According to Joshua Miller, the bender characters\' use of bending for everyday activities brings "depth and believability" to the avatar world. Miller called the series\' designs "rich and immersive", with each nation having its own, detailed look. He praised the action scenes as "well rendered", comparing the development of the avatar world to that of "The Lord of the Rings", and the fight choreography as "wonderful in its most minor details". D. F. Smith enjoyed the series\' painstaking backgrounds. "Cricket" Te praised each episode\'s color palette and the choreography\'s combination of martial arts and magic. Nick Hartel criticized the animation, although he found it an improvement over previous Nickelodeon shows. Chris Mitchell called the animation fluid. "Cricket" Te agreed, noting its manga influence. According to Brittany Lovely, non-bender characters in battle are "overshadowed" by their bender counterparts. Joe Corey called the animation\'s action and environments a "great achievement", and Rob Keyes praised the series\' fight choreography. According to Kirk Hamilton, the action sequences in the series are amazing while being child-appropriate and exciting.\n'),
#  ('37179919',
#   'Paradise (Lana Del Rey EP)',
#   74,
#   'BULLET::::- Jordan Stilwell – additional recording\n'),
#  ('284356',
#   'Oscar Robertson',
#   77,
#   'BULLET::::- Indiana Basketball Hall of Fame profile\n'),
#  ('36010728',
#   'Music video director',
#   16,
#   'BULLET::::- The tvc director global database\n'),
#  ('525270', 'Kill Bill: Volume 2', 57, 'BULLET::::- "Kill Buljo"\n'),
#  ('525669',
#   'Kolyma',
#   109,
#   'BULLET::::- Russian map of the Gulag camps across the Soviet Union at the Memorial website\n'),
#  ('3354', 'Berlin', 214, 'BULLET::::- Berlin.de – Official website\n'),
#  ('216072', 'Home Alone', 90, 'BULLET::::- "Home Alone" at The Numbers\n'),
#  ('4276475',
#   'The Dark Knight (film)',
#   102,
#   'BULLET::::- "The Dark Knight": Blu-ray Disc Review at HD Report\n'),
#  ('3356',
#   'Bill Clinton',
#   216,
#   'BULLET::::- "Clinton"\xa0an "American Experience" documentary\n'),
#  ('80864',
#   'Stone Temple Pilots',
#   76,
#   'BULLET::::- "Stone Temple Pilots" (2018)\n'),
#  ('46991482',
#   'Pitch Perfect 3',
#   58,
#   'When asked about a sequel to "Pitch Perfect 3", director Trish Sie said, "Of course that\'s above my pay grade and I have no idea and am not the one making the decisions but as far as I am concerned, I would see these movies on and on and on until they start sucking. I think whether it\'s these women in the next stage of life or it\'s a new group of women going through these things, I think there are endless ways to chart the course of the girls\' lives and a woman\'s life." Rebel Wilson posted a picture on social media alongside Brittany Snow, Anna Camp and Chrissie Fit all holding up 4 fingers. This potentially means that Universal might be making a fourth Pitch Perfect movie.\n'),
#  ('13039867',
#   'Twilight (novel series)',
#   73,
#   "BULLET::::- Stephenie Meyer's website\n"),
#  ('49547315',
#   'Marcus Rashford',
#   45,
#   'BULLET::::- Profile at the Football Association website\n'),
#  ('635041',
#   'Anderson Cooper',
#   80,
#   'BULLET::::- Anderson Cooper: The Silver Fox\xa0– slideshow by "Life magazine"\n'),
#  ('81425',
#   'Brian Wilson',
#   142,
#   'BULLET::::- Brian Wilson\'s Wave by Peter Ames Carlin, "American Heritage", August/September 2004.\n'),
#  ('22989',
#   'Paris',
#   289,
#   'BULLET::::- Shack, William A. "Harlem in Montmartre, A Paris Jazz Story between the Great Wars", University of California Press, 2001. ,\n'),
#  ('39484514',
#   'The Homesman',
#   42,
#   'Claudia Puig with "USA Today" wrote: "Set on the Great Plains in the mid-1800s, \'The Homesman\' aims for a story that\'s poignant and told sparely, but comes across as mawkish, tedious and self-indulgent. Swank brings a gravitas to her character that is undermined when some of her antics are played for laughs. In a 10-minute cameo, Meryl Streep\'s character is more fully developed than any of the leads\' roles. The story attempts to show how hard it was for women in the Old West, but it ends up being Jones\' surly show".\n'),
#  ('23041',
#   'Puerto Rico',
#   335,
#   'United Nations (U.N.) Declaration on Puerto Rico\n'),
#  ('3735', 'Beastie Boys', 130, 'BULLET::::- Beastie Boys Lyrics\n'),
#  ('3747',
#   'Bill Gates',
#   111,
#   'BULLET::::- "The Meaning of Bill Gates: As his reign at Microsoft comes to an end, so does the era he dominated", "The Economist", June 28, 2008.\n'),
#  ('772173', 'Maria Sharapova', 212, 'Specific\n'),
#  ('39490590',
#   'Pawn Sacrifice',
#   48,
#   'BULLET::::- "Pawn Sacrifice" at "History vs. Hollywood"\n'),
#  ('356304', 'Psychological horror', 56, 'BULLET::::- Unreliable narrator\n'),
#  ('3969',
#   'Buckingham Palace',
#   85,
#   'BULLET::::- The State Rooms, Buckingham Palace at the Royal Collection Trust\n'),
#  ('47737',
#   'Las Vegas',
#   173,
#   'BULLET::::- National Weather Service Forecast – Las Vegas, NV\n'),
#  ('19084502',
#   'Michael Phelps',
#   182,
#   'BULLET::::- Official website of the Michael Phelps Foundation\n'),
#  ('36044408',
#   'Adam Driver',
#   29,
#   'BULLET::::- Adam Driver: Theatre Credits on Broadwayworld.com\n'),
#  ('81854',
#   'Central venous catheter',
#   83,
#   'BULLET::::- Central venous line care, comparison, indications, complications and uses\n'),
#  ('3155871',
#   'Event management',
#   36,
#   'BULLET::::- Goldblatt, Joe. "Twenty-First Century Global Event Management" (The Wiley Event Management Series)\n'),
#  ('47019680',
#   'Sully (film)',
#   62,
#   'BULLET::::- "Sully" at "History vs. Hollywood"\n'),
#  ('14941280',
#   'Ratatouille (film)',
#   75,
#   "At the 2017 D23 Expo, Disney announced a similar, Ratatouille-based attraction would be built at the France Pavilion in Epcot's World Showcase by 2021.\n"),
#  ('23087494',
#   'Lily Collins',
#   27,
#   'Collins is an outspoken anti-bullying advocate and is serving as a Celebrity Ambassador to anti-bullying organization Bystander Revolution, founded by author MacKenzie Bezos.\n'),
#  ('4147',
#   'Bali',
#   133,
#   'BULLET::::- Covarrubias, Miguel (1946). "Island of Bali".\n'),
#  ('4173',
#   'Babe Ruth',
#   175,
#   "BULLET::::- In March 2011, the VOA Special English service of the Voice of America broadcast a 15-minute program on Babe Ruth. A transcript and MP3 of the program, intended for English learners, can be found at Babe Ruth,1895–1948: America's Greatest Baseball Player\n"),
#  ('125248',
#   'Charles, Prince of Wales',
#   123,
#   "BULLET::::- Official website of 'The Prince's Trust'\n"),
#  ('82533',
#   'International relations',
#   165,
#   'BULLET::::- The European Institute for International Law and International Relations\n'),
#  ('164640', 'Steffi Graf', 120, "BULLET::::- Steffi Graf's victories\n"),
#  ('23440',
#   'Philippines',
#   268,
#   'BULLET::::- WikiSatellite view of Philippines at WikiMapia\n'),
#  ('22114132',
#   'The Avengers (2012 film)',
#   108,
#   'BULLET::::- The Battle of New York: An "Avengers" Oral History at Thrillist\n'),
#  ('164989',
#   'Loss of supply',
#   11,
#   'BULLET::::- On 9 March 2011, the Legislative Council of Hong Kong blocked a resolution for provisional appropriations, which, before 2011, had always been a matter of formality. Resolutions for provisional appropriations had never been voted by division until 2011. The government decided, on the following day, to table another resolution with a minor change being made merely for the sake of circumventing procedural requirements that a negatived question cannot be tabled again.\n'),
#  ('776049',
#   'Harry Potter and the Deathly Hallows',
#   98,
#   'BULLET::::- Australia-New Zealand publisher book information\n'),
#  ('1085284', 'Ajay Devgn', 70, 'BULLET::::- Official Site\n'),
#  ('48377733',
#   'John Wick: Chapter 2',
#   59,
#   'In October 2016, Stahelski stated that a third film, titled "John Wick: Chapter 3 – Parabellum", is in the works and in June 2017 it was reported that Kolstad will return to write the screenplay. In September 2017, Lionsgate set the sequel\'s release date for May 17, 2019. In January 2018, it was reported that Stahelski will return to direct with Hiroyuki Sanada in talks to join the cast. In February 2018, it was reported that in addition to Reeves, McShane, Fishburne and Reddick would each reprise their roles from the film, with filming set to commence April 26, 2018, in New York City and Montreal.\n'),
#  ('4335',
#   'Batman',
#   187,
#   'BULLET::::- Batman (1940 - present) Comics Inventory\n'),
#  ('23580',
#   'Paleogene',
#   20,
#   'BULLET::::- Paleogene (chronostratigraphy scale)\n'),
#  ('165348',
#   'Ayutthaya Kingdom',
#   163,
#   'BULLET::::- Ayutthaya Historical Research\n'),
#  ('47060975',
#   'Jon Watts',
#   12,
#   'Watts directed the film\'s 2019 sequel "". Watts reportedly became increasingly devoted to the franchise, even starting his own extensive collection of rare spiders.\n'),
#  ('4408',
#   'Buddy Holly',
#   86,
#   'BULLET::::- Buddy Holly – sessions and cover songs\n'),
#  ('4402',
#   'Brown bear',
#   169,
#   'BULLET::::- Ancient Fossil Offers New Clues To Brown Bears Past\n'),
#  ('82976',
#   'Taj Mahal',
#   75,
#   'BULLET::::- Profile of the Taj Mahal at UNESCO\n'),
#  ('27005455', 'Bruno Mars', 114, 'BULLET::::- List of Puerto Ricans\n'),
#  ('12292280',
#   'Mr. Nobody (film)',
#   64,
#   'BULLET::::- "Mr. Nobody at Magnolia Pictures\n'),
#  ('165527',
#   'Angela Lansbury',
#   92,
#   'BULLET::::- Interview with Christine Amanpour "40 years later, Angela Lansbury returns to the London stage – at 88"\n'),
#  ('288210',
#   'Gary Ridgway',
#   99,
#   "BULLET::::- A copy of Ridgway's infamous letter to the press (PDF)\n"),
#  ('288360',
#   'Gia',
#   39,
#   'BULLET::::- Angelina Jolie – Outstanding Performance by a Female Actor in a Television Movie or Miniseries\n'),
#  ('4477',
#   'The Beach Boys',
#   245,
#   'BULLET::::- Bellagio 10452 – unofficial Beach Boys reference site\n'),
#  ('935048',
#   'Monarch of the Glen (TV series)',
#   39,
#   'In 2002, the series was spoofed in popular BBC television sketch series "French and Saunders" for their "Celebrity Christmas Puddings" special and was named "Monarch of the Glum". Alastair Mackenzie himself appeared in his role of Archie. Dawn French appeared as Lexie MacDonald, Jennifer Saunders as Molly MacDonald.\n'),
#  ('27007631',
#   'Mr. Sunshine (2011 TV series)',
#   20,
#   'Mill Creek Entertainment announced the re-released of the complete series on DVD.\n'),
#  ('2867396',
#   'George Tuska',
#   193,
#   "BULLET::::- Scorchy Smith at Don Markstein's Toonopedia. Archived October 25, 2011.\n"),
#  ('25001260',
#   'Transformers: Dark of the Moon',
#   129,
#   'BULLET::::- List of highest-grossing films\n'),
#  ('936829',
#   'Zooey Deschanel',
#   47,
#   'BULLET::::- Zooey Deschanel Video produced by ""\n'),
#  ('17157119',
#   'Friendship',
#   69,
#   'BULLET::::- Friendship at the "Stanford Encyclopedia of Philosophy"\n'),
#  ('83538',
#   'Leslie Howard',
#   85,
#   'BULLET::::- Leslie Howard: The Man Who Gave A Damn (2015) by Repo Films\n'),
#  ('44164132', 'Moana (2016 film)', 86, 'BULLET::::- Austronesian peoples\n'),
#  ('2072812',
#   'Frank (Amy Winehouse album)',
#   80,
#   'BULLET::::- A B&S Classic Interview Before \'Rehab\' at "Blues & Soul"\n'),
#  ('4310106', 'Dirt (TV series)', 52, 'BULLET::::- Dirt at The Futon Critic\n'),
#  ('18279525',
#   'Ajab Prem Ki Ghazab Kahani',
#   59,
#   'The soundtrack received generally favorable reviews from critics. Samir Dave of Planet Bollywood gave it a rating of 7.5/10 and said, "If you are looking for an enjoyable potpourri of different musical styles, and melody, then you will love what Pritam has served up for, "Ajab Prem Ki Ghazab Kahani". It deserves to be at the top of the charts". Joginder Tuteja of Bollywood Hungama rated it 3.5/5 and praised the music composer saying, "This is Pritam\'s year, delivering chartbusters by dozens all through the year, he can now look forward to another bountiful of hit songs up his sleeves with Ajab Prem Ki Ghazab Kahani. Also, Ranbir and Katrina can enjoy a hugely popular track for themselves in the form of \'Main Tera Dhadkan Teri\'. Go, pick this one up from the shelves!". The songs \'Tu Jaane Na\', \'Tera Hone Laga Hoon\', \'Prem Ki Naiya\' and \'Mein Tera Dhadkan Teri\' became chartbusters.\n'),
#  ('12311469',
#   'Underworld (film series)',
#   48,
#   'A cross-over with the film "I, Frankenstein" or its sequels was planned by Kevin Grevioux, creator of the "I, Frankenstein" graphic novel. He stated in a pre-release interview that, in an early draft of his screenplay, Beckinsale would have made a post-credit cameo appearance as Selene and that there would have been "Underworld" easter eggs, but none of this was used.\n'),
#  ('4727',
#   'Batman (1966 film)',
#   54,
#   'BULLET::::- kiddiematinee.com: BATMAN (1966, U.S.)\n'),
#  ('2557423',
#   'Julius Caesar (1953 film)',
#   123,
#   'BULLET::::- "Julius Caesar" at "TV Guide" (1987 write-up was originally published in "The Motion Picture Guide")\n'),
#  ('27035619',
#   'All the Lovers',
#   67,
#   'BULLET::::- List of number-one dance singles of 2010 (U.S.)\n'),
#  ('166103',
#   'David Hasselhoff',
#   77,
#   'BULLET::::- Q&A, "The Guardian", April 11, 2009.\n'),
#  ('4736039',
#   'Trevor Baxter',
#   11,
#   'On 17 July 2017, it was announced that Trevor Baxter had died the previous day. The cause of the death is currently unknown.\n'),
#  ('2560289',
#   'Hot (Mel B album)',
#   7,
#   'Credits adapted from the liner notes of "Hot".\n'),
#  ('14995351',
#   'Michael Jackson',
#   173,
#   "BULLET::::- Michael Jackson at the FBI's website\n"),
#  ('38403311',
#   'Everybody Needs a Best Friend',
#   8,
#   'Norah Jones performed the song live for the first time on "The Tonight Show with Jay Leno". Jones performed the song at the 85th Academy Awards ceremony on February 24, 2013. Seth MacFarlane performed the song on August 2014 at the Hollywood Bowl during a John Williams concert.\n'),
#  ('8955445', 'O. J. Simpson', 105, 'BULLET::::- O. J. Simpson robbery case\n'),
#  ('3177114', '1991 NBA Finals', 47, 'BULLET::::- NBA History\n'),
#  ('39552119',
#   'The Entire History of You',
#   27,
#   'BULLET::::- The Final Cut (2004 film)\n'),
#  ('18307757',
#   'Ellen DeGeneres',
#   67,
#   'BULLET::::- "The Ellen DeGeneres Show"\n'),
#  ('166470',
#   'Ricin',
#   70,
#   'BULLET::::- Emergency Response Card – Ricin at CDC\n'),
#  ('49650',
#   'Dan Aykroyd',
#   68,
#   'BULLET::::- Dan Aykroyd, Still Full of the \'Blues\'\xa0– interview on NPR\'s "Fresh Air" with Terry Gross\xa0– originally aired November 22, 2004\n'),
#  ('40753440', 'No Escape (2015 film)', 40, 'BULLET::::- 05-03-2015\n'),
#  ('7529378', 'Facebook', 264, 'BULLET::::- Double Irish tax scheme\n'),
#  ('535335',
#   'War of the Worlds (2005 film)',
#   83,
#   'BULLET::::- "War of the Worlds" at Facebook\n'),
#  ('49706', 'Paul Newman', 96, 'BULLET::::- Paul Newman at Emmys.com\n'),
#  ('49728',
#   'San Francisco',
#   209,
#   'BULLET::::- Virtual Museum of the City of San Francisco\n'),
#  ('85370',
#   'Bob Arum',
#   40,
#   'BULLET::::- BoxingInsider.com Biofile interview with Bob Arum\n'),
#  ('1092923', 'Google', 127, 'BULLET::::- Corporate homepage\n'),
#  ('645042',
#   'New York City',
#   259,
#   'BULLET::::- Collections, 145,000 NYC photographs at Museum of the City of New York\n'),
#  ('166911', 'Stevie Ray Vaughan', 112, 'BULLET::::- Music of Texas\n'),
#  ('50239', 'Led Zeppelin II', 66, 'Sources\n'),
#  ('12330092',
#   "Girls' Generation",
#   107,
#   'BULLET::::- List of best-selling girl groups\n'),
#  ('25169',
#   'Quentin Tarantino',
#   98,
#   'BULLET::::- Quentin Tarantino Film Festival, a film festival in Austin, Texas, United States, hosted by Tarantino.\n'),
#  ('292511',
#   'Caroline, Princess of Hanover',
#   85,
#   "BULLET::::- Caroline, Princess of Hanover at the Prince's Palace of Monaco\n"),
#  ('2316131',
#   'Nikolaj Coster-Waldau',
#   32,
#   "In early 2018, he and several other Danish artists signed a manifesto demanding zero tolerance for sexism, sexual harassment and sexual assault in the Danish film and stage arts industry. In June 2018, he kicked off The Lion's Share fund's launch, an action in which when an advertising campaign uses an image of an animal, the advertiser will donate 0.5% of the paid media spending of that campaign to the fund.\n"),
#  ('222445',
#   'Rob Lowe',
#   47,
#   'In December 2017, Lowe was chosen to receive the Horatio Alger Award for 2018. The Horatio Alger Association of Distinguished Americans recognizes people who have overcome personal challenges to achieve personal and professional success.\n'),
#  ('167378',
#   'Venus Williams',
#   396,
#   '[[Category:World No. 1 tennis players]]\n'),
#  ('1645054', 'Giada De Laurentiis', 26, 'BULLET::::- Food Network profile\n'),
#  ('1645518',
#   'Massachusetts',
#   182,
#   'BULLET::::- Massachusetts State Guide from the Library of Congress\n'),
#  ('25992485',
#   'Fujitsu iPAD',
#   2,
#   "The Fujitsu iPAD is a lightweight handheld device that was introduced by Fujitsu, in 2002. It runs Microsoft's CE.NET operating system. It supports 802.11b wireless LAN to connect wirelessly with other company infrastructure. The device can support inventory management as well as credit card payments. In January 2010, when Apple announced the Apple iPad, there was a naming controversy between the two devices. To settle the trademark infringement allegation, Apple purchased the trademark rights from Fujitsu. Some trademark analysts estimate that Apple paid Fujitsu over US$4\xa0million in exchange for the March 17, 2010 assignment of Fujitsu's iPad trademark rights to Apple. \n"),
#  ('787704',
#   'Arsenic and Old Lace (film)',
#   57,
#   'BULLET::::- Arsenic and Old Lace and Peter Lorre\n'),
#  ('1255496',
#   'Margot Kidder',
#   53,
#   'BULLET::::- Brodesser-Akner, Taffy. "Margot Kidder," "New York Times," Dec. 27, 2018.\n'),
#  ('24067121',
#   'De Profundis (letter)',
#   66,
#   'BULLET::::- (1912), a poem by Florence Earle Coates.\n'),
#  ('6873934',
#   'Steve Irwin',
#   72,
#   'BULLET::::- Ocean Treasures Memorial Library/Steve Irwin Memorial\n'),
#  ('223253',
#   'John Cusack',
#   26,
#   'BULLET::::- Robinson, Tasha Onion A.V. Club interview, November 27, 2007\n'),
#  ('87446',
#   'Parliament of Canada',
#   69,
#   'BULLET::::- Open Parliament: MP vote and speech tracker - keep tabs on Parliament\n'),
#  ('50548', 'Oakland, California', 236, 'BULLET::::- Rotary Club of Oakland\n'),
#  ('50605',
#   'Cerebral palsy',
#   162,
#   'BULLET::::- Cerebral Palsy Information Page at NINDS\n'),
#  ('4752795',
#   'Before Night Falls (film)',
#   47,
#   'BULLET::::- 2000: Academy Awards: Best Actor: Javier Bardem\n'),
#  ('223902', 'Klute', 55, 'BULLET::::- List of American films of 1971\n'),
#  ('5645', 'Cult film', 57, 'BULLET::::- Sleeper hit\n'),
#  ('50745',
#   'Paul Simon',
#   151,
#   'BULLET::::- Talking about Paul Simon at Emory University (Videos)\n'),
#  ('167805',
#   'Gwen Stefani',
#   65,
#   'BULLET::::- Machaca Fest • Monterrey, Mexico (Headliner, 2019)\n'),
#  ('8980330',
#   'WALL-E',
#   97,
#   'BULLET::::- Mars Cube One, which is nicknamed WALL-E\n'),
#  ('6237038',
#   'Prakash Jha',
#   66,
#   'BULLET::::- Prakash Jha Productions website\n'),
#  ('87624',
#   'Mickey Rooney',
#   137,
#   'BULLET::::- Interview with Hollywood Reporter, July 2010\n'),
#  ('31575693',
#   'Kumail Nanjiani',
#   19,
#   'In 2007, Nanjiani married Emily V. Gordon, an author, comedy producer, and former couples and family therapist in Chicago City Hall. Gordon was the booker and producer of "The Meltdown with Jonah and Kumail" (2014–2016). Nanjiani was raised as a Shia Muslim but is at present not practising and is agnostic.\n'),
#  ('43066389',
#   'Got a Girl',
#   16,
#   'BULLET::::- "There\'s a Revolution" (2014)\n'),
#  ('5655',
#   'Courtney Love',
#   92,
#   'BULLET::::- Works by or about Courtney Love (library search via WorldCat)\n'),
#  ('25423',
#   'Rock music',
#   150,
#   'BULLET::::- Szatmary, David P. "Rockin\' in Time: a Social History of Rock-and-Roll". Third ed. Upper Saddle River NJ: Prentice-Hall, 1996. xvi, 320 p., ill., mostly with b&w photos.\n'),
#  ('25433',
#   'Ronald Reagan',
#   230,
#   "BULLET::::- Ronald Reagan's Personal Manuscripts\n"),
#  ('1256799', 'Lee Child', 75, 'BULLET::::- Times, 25 August 2012\n'),
#  ('21222169',
#   'James McAvoy',
#   33,
#   'BULLET::::- James McAvoy news coverage at "The Guardian"\n'),
#  ('24083267',
#   'Your Highness',
#   39,
#   'James Franco would later poke fun at the film\'s poor reception during his Comedy Central Roast, saying “I agreed to do this roast because I wanted to do something I’ve never done before — something that has zero artistic value, something nobody will remember three months from now, something that’s offensive, homophobic, and stars horrifically untalented people and something that’s only a big deal to a handful of teenage stoners on Twitter. You might say, ‘James, didn’t you just describe "Your Highness"?\' I wouldn’t know, I didn’t see "Your Highness".” On his first-ever interview on "The Howard Stern Show" to promote the film "Spring Breakers", Franco was surprised to hear Stern compliment "Your Highness", asking incredulously, "you liked that?" He attributed the film\'s lackluster performance to its "tricky" blend of lowbrow humor and medieval swords and sorcerers, a combination that hadn\'t worked well since "Monty Python and the Holy Grail".\n'),
#  ('5769',
#   'C. S. Forester',
#   98,
#   'BULLET::::- C. S. Forester on "You Bet Your Life" in 1956\n'),
#  ('444267', 'Legally Blonde', 79, 'BULLET::::- Legally Blonde (franchise)\n'),
#  ('25473',
#   'Richard Nixon',
#   193,
#   'BULLET::::- Richard Nixon Personal Manuscripts\n'),
#  ('168269',
#   'Dayton Agreement',
#   100,
#   'BULLET::::- All Peace Agreements in Bosnia, UN Peacemaker\n'),
#  ('649100', 'Adderall', 55, 'BULLET::::- Image legend\n'),
#  ('2578570', 'Spread (food)', 10, 'BULLET::::- Lists of foods\n'),
#  ('168310', 'Daft Punk', 80, 'BULLET::::- "Daft Punk" on Eurochannel\n'),
#  ('791546',
#   'Ketogenic diet',
#   116,
#   "BULLET::::- Lurie Children's Hospital: How the Ketogenic Diet Works.\n"),
#  ('5884',
#   'Charles Dickens',
#   152,
#   'BULLET::::- Plaques Historical plaques about Charles Dickens, on Open Plaques website\n'),
#  ('4764846',
#   'Usain Bolt',
#   226,
#   "BULLET::::- All of Usain Bolt's Olympic Games finals via the Olympic Channel on YouTube\n"),
#  ('25734',
#   'Taiwan',
#   238,
#   'BULLET::::- Taiwan, The Heart of Asia, Tourism Bureau, Republic of China (Taiwan)\n'),
#  ('33757322',
#   'Escape from Planet Earth',
#   50,
#   'BULLET::::- Production notes\n'),
#  ('25832', 'Ringo Starr', 122, 'BULLET::::- The art of Ringo Starr\n'),
#  ('6121', 'Central America', 135, 'BULLET::::- Teaching Central America\n'),
#  ('1262555', 'Ad-Rock', 26, 'BULLET::::- "Simply Mortified" (2000)\n'),
#  ('4342453', 'Chris Hardwick', 48, 'BULLET::::- "Funcomfortable" (2016)\n'),
#  ('45506550',
#   'American Horror Story: Hotel',
#   87,
#   'BULLET::::- List of "American Horror Story" episodes at TV.com\n'),
#  ('10746393',
#   'No Reservations (film)',
#   36,
#   'BULLET::::- List of American films of 2007\n'),
#  ('9016038',
#   'Curly Top (film)',
#   47,
#   'BULLET::::- In her essay "Cuteness and Commodity Aesthetics: Tom Thumb and Shirley Temple", Lori Merish examines \'the cult of cuteness\' in America.\n'),
#  ('366111', 'Shallow Hal', 58, 'BULLET::::- Shallow Hal Official Fox site\n'),
#  ('40816159',
#   'Steven Price (composer)',
#   45,
#   'In December 2013, the Dallas–Fort Worth Film Critics Association awarded him the Best Musical Score honor for his work on "Gravity".\n'),
#  ('542300',
#   'Ilkhanate',
#   75,
#   'BULLET::::- Searchable database for Ilkhanid coins\n'),
#  ('26193',
#   'Roger Penrose',
#   97,
#   'BULLET::::- A chess problem holds the key to human consciousness?, Chessbase\n'),
#  ('18369401',
#   'Sons of Anarchy',
#   190,
#   'In 2018, Universo announced an October 29, 2018 premiere of "Sons of Anarchy" season 3 in Spanish. The show was made available on Netflix in 2011, but all seasons were removed from Netflix on December 1, 2018. \n'),
#  ('5792809',
#   'Angelina Jolie',
#   106,
#   'BULLET::::- Membership at the Council on Foreign Relations\n'),
#  ('88678', 'The Lion King', 107, 'BULLET::::- "Hamlet"\n'),
#  ('6610',
#   'Carolina Panthers',
#   87,
#   'BULLET::::- Carolina Panthers at NFL.com\n'),
#  ('88923', 'Snoop Dogg', 140, 'BULLET::::- Snoopdog TV on YouTube\n'),
#  ('43117078',
#   'Bridge of Spies (film)',
#   65,
#   'BULLET::::- Hollow Nickel Case\n'),
#  ('31615401',
#   'Game of Thrones (season 1)',
#   134,
#   'BULLET::::- Making "Game of Thrones" on HBO.com\n'),
#  ('129644',
#   'The Godfather Part III',
#   70,
#   'BULLET::::- Included in "The Godfather DVD Collection".\n'),
#  ('44319609',
#   "Robert J. O'Neill (Navy SEAL)",
#   22,
#   "BULLET::::- Leading Authorities Speakers Bureau – Robert O'Neill\n"),
#  ('28229246', 'Paul Pogba', 101, 'BULLET::::- Profile at Lega Serie A\n'),
#  ('52124',
#   'VHS',
#   165,
#   'BULLET::::- VHSCollector.com: Analog Video Cassette Archive A growing archive of commercially released video cassettes from their dawn to the present, and a guide to collecting.\n'),
#  ('26709',
#   'Sean Connery',
#   54,
#   'BULLET::::- young Sean body building pose, 1950s\n'),
#  ('21260255',
#   'Scott Eastwood',
#   13,
#   'Scott bears a striking resemblance to his father. This was reported when he dressed up as the character played by Clint Eastwood in "The Good, the Bad and the Ugly" for a Halloween charity event in 2016.\n'),
#  ('368204', 'Faith Evans', 77, 'BULLET::::- "Vibe" interview, 2005\n'),
#  ('45535168',
#   'Asteroid Day',
#   16,
#   'In its resolution the United Nations declares "30 June International Asteroid Day to observe each year at the international level the anniversary of the Tunguska impact over Siberia, Russian Federation, on 30 June 1908 and to raise public awareness about the asteroid impact hazard."\n'),
#  ('170438', 'Heather Graham', 42, 'BULLET::::- Heather Graham at TV.com\n'),
#  ('26830',
#   'Slovakia',
#   228,
#   'BULLET::::- Key Development Forecasts for the Slovak Republic from International Futures\n'),
#  ('657159',
#   'Conquest of the Planet of the Apes',
#   44,
#   'BULLET::::- List of American films of 1972\n'),
#  ('16100029',
#   'Novak Djokovic',
#   225,
#   'BULLET::::- Novak Djokovic Foundation\n'),
#  ('170977',
#   'Hugo Weaving',
#   44,
#   'BULLET::::- |%20Number%3A;querytype=;resCount=10 Hugo Weaving at the National Film and Sound Archive\n'),
#  ('19230767',
#   'Odin',
#   109,
#   'BULLET::::- MyNDIR (My Norse Digital Image Repository) Illustrations of Óðinn from manuscripts and early print books. Clicking on the thumbnail will give you the full image and information concerning it.\n'),
#  ('21282769', 'Kick-Ass (film)', 98, 'BULLET::::- Vigilante film\n'),
#  ('299717',
#   'Courteney Cox',
#   30,
#   'BULLET::::- 2010: Honored with the Lucy Award by the Women in Film Crystal + Lucy Awards.\n'),
#  ('34986696',
#   'Wentworth (TV series)',
#   71,
#   'BULLET::::- "Orange Is the New Black", American drama with a similar premise\n'),
#  ('451733', 'Justin Trudeau', 135, 'BULLET::::- House of Commons profile\n'),
#  ('804581',
#   'Anne Frank',
#   104,
#   'BULLET::::- Online exhibition about the family history of Anne Frank\n'),
#  ('452061',
#   'Charles Marie de La Condamine',
#   30,
#   'BULLET::::- Voyages of Discovery : The Figure of Earth (BBC documentary) / https://www.youtube.com/watch?v=LKulxEp2aqk\n'),
#  ('1473889',
#   'Michael Winterbottom',
#   125,
#   'BULLET::::- Resonance FM radio interview — "Reality Check: Michael Winterbottom’s Code 46" "PanelBorders.Wordpress.com"\n'),
#  ('6269899',
#   'Troy Baker',
#   26,
#   'BULLET::::- Troy Baker at Behind The Voice Actors\n'),
#  ('27318',
#   'Singapore',
#   182,
#   'BULLET::::- WikiSatellite view of Singapore at WikiMapia\n'),
#  ('27338',
#   'Slovenia',
#   286,
#   'BULLET::::- Slovenian Press Agency. News in English.\n'),
#  ('3955038',
#   'Kafka (film)',
#   30,
# ...
#  ('178826', 'Joaquin Phoenix', 66, 'BULLET::::- "Earthlings"\n'),
#  ('20482468',
#   'Oh Yeon-seo',
#   25,
#   'BULLET::::- Oh Yeon-seo (오연서) on HanCinema\n'),
#  ('1696008',
#   'Beautiful (Christina Aguilera song)',
#   68,
#   'BULLET::::- List of Romanian Top 100 number ones of the 2000s\n'),
#  ('12232',
#   'Gustave Eiffel',
#   137,
#   'BULLET::::- Einsturz der Birsbrücke bei Münchenstein (Basel)\n'),
#  ('12240', 'Gold', 186, 'BULLET::::- , www.epa.gov\n'),
#  ('12301',
#   'A Song of Ice and Fire',
#   110,
#   'BULLET::::- So Spake Martin, Collection of statements, correspondences and interviews by George R. R. Martin.\n'),
#  ('97778', 'Slash (musician)', 75, 'BULLET::::- "Libertad" (2007)\n'),
#  ('43386202',
#   'Roman Atwood',
#   23,
#   'In March 2014, Roman, along with his accomplices, were arrested by the Columbus Police Department for inducing panic and disorderly conduct during the filming of a prank where he pretended to rob an ATM in public. He was released on bail and was summoned to court. The case was widely contested, with his fans showing up to court to support and watch the case. As a defendant, he won the case on the basis of expression of art and freedom of speech, and the case was settled.\n'),
#  ('21490998',
#   'Burundi',
#   148,
#   'BULLET::::- Key Development Forecasts for Burundi from International Futures\n'),
#  ('468899',
#   'Patrick Bateman',
#   34,
#   'BULLET::::- 2003: Ellis kills off Patrick Bateman by writing an account of the serial killer being trapped in a pier fire. See "Lunar Park".\n'),
#  ('34028475',
#   'Little Mix',
#   74,
#   'BULLET::::- Ariana Grande – Dangerous Woman Tour (2017)\n'),
#  ('7047921',
#   'Little Miss Sunshine',
#   67,
#   'BULLET::::- Arndt, Michael. "Little Miss Sunshine: The Shooting Script". Newmarket, 2007. .\n'),
#  ('179331',
#   'Will Ferrell',
#   77,
#   'BULLET::::- Will Ferrell page on Funny Or Die\n'),
#  ('21492751',
#   'Nelson Mandela',
#   149,
#   "BULLET::::- Nelson Mandela's family tree\n"),
#  ('138483', 'Richard Harris', 134, 'BULLET::::- Dumbledore Quotes site\n'),
#  ('98301',
#   'Joker (character)',
#   78,
#   'The Joker has also been featured in video games. Hamill returned to voice the character in 2009\'s critically acclaimed "", its equally praised 2011 sequel "" and the multiplayer "DC Universe Online". Hamill was replaced by Troy Baker for the 2013 prequel, "", and the "Arkham" series\' animated "", while Hamill returned for the 2015 series finale, "". Richard Epcar voiced the Joker in the 2008 fighting game, "Mortal Kombat vs. DC Universe", 2013\'s "", and 2017\'s "Injustice 2". The character also appeared in "" (2008), "" (2012) and its , and "" (2014) (the latter three voiced by Christopher Corey Smith). Anthony Ingruber voices the Joker in "" (2016) and "" (2017).\n'),
#  ('2392110',
#   'Audrey Horne',
#   26,
#   'BULLET::::- Audrey Horne "Twin Peaks" card\n'),
#  ('20500762',
#   'Ronaldo Maczinski',
#   2,
#   'Ronaldo Maczinski (born 11 September 1980), known as Ronaldo, is a Brazilian footballer who plays as a forward; he had a lengthy career in Portuguese football.\n'),
#  ('7757109',
#   'Miss Selfridge',
#   19,
#   'BULLET::::- Miss Selfridge - Fashion Fast Forward Malaysia\n'),
#  ('388018',
#   'The Amanda Show',
#   71,
#   'BULLET::::- Official website archived from the original on June 14, 2006\n'),
#  ('570280',
#   'Foo Fighters',
#   89,
#   'On February 12, 2012, the band performed at the 54th Annual Grammy Awards playing "Walk" along with the remix version of "Rope", featuring deadmau5. The band was nominated for six Grammy Awards, including Album of the Year, Best Rock Performance, Best Hard Rock/Metal Performance, Best Rock Song, Best Rock Album and Best Long Form Music Video (for ""). They won five out of the six, losing only to Adele in the Album of the Year category.\n'),
#  ('570559', 'Star Search', 54, '[[Category:Operation Prime Time]]\n'),
#  ('99372',
#   'Robin (character)',
#   87,
#   'BULLET::::- Extensive biography on Tim Drake\n'),
#  ('34042335',
#   'Ramayanam (1996 film)',
#   41,
#   'Upon release, the film received positive reviews from critics.\n'),
#  ('691693',
#   'Inhumans',
#   123,
#   "BULLET::::- The Inhumans at Don Markstein's Toonopedia. Archived from the original on September 17, 2016.\n"),
#  ('9233381',
#   'Ryan Seacrest',
#   57,
#   'BULLET::::- DigitalReview.net Biography and reviews of Ryan Seacrest\n'),
#  ('46262761',
#   'In Dubious Battle (film)',
#   44,
#   'Boyd van Hoeij of "The Hollywood Reporter" simply called the film and Franco as "uneven" but also states that "if "In Dubious Battle" remains watchable, it\'s because Wolff really sells his character\'s doubts, growth and sobering reality checks".\n'),
#  ('246309',
#   'Vincent Cassel',
#   27,
#   'BULLET::::- CNN interview with Vincent Cassel\n'),
#  ('36483433',
#   'Divergent (film)',
#   81,
#   'BULLET::::- Divergent: production notes, tour // Summit Entertainment (copy of pdf)\n'),
#  ('246559',
#   'Peggy Sue Got Married',
#   51,
#   'The Chinese comedy film "Goodbye Mr. Loser" (2015) has been criticized for its similarities in plot with "Peggy Sue Got Married". Two weeks after its premiere, Chinese netizens started posting articles online comparing similar plot elements of the film with those from the 1986 American film. The directors of "Goodbye Mr. Loser" have denied the allegations of plagiarism with a statement claiming that their film is an adaptation of a theater play which was inspired by a post on a Chinese Internet forum in 2010.\n'),
#  ('314475', 'Carrie Fisher', 78, 'BULLET::::- Carrie Fisher(Aveleyman)\n'),
#  ('35300735',
#   'The Hangover Part III',
#   54,
#   'Christy Lemire of the Associated Press gave the film a positive review, writing, ""The Hangover Part III" runs a different sort of risk by going to darker and more dangerous places than its predecessors, both artistically and emotionally. It dares to alienate the very audience that made "The Hangover" the highest-grossing R-rated comedy of all time."\n'),
#  ('57802',
#   'Newcastle United F.C.',
#   99,
#   'BULLET::::- Newcastle United News\xa0– Sky Sports\n'),
#  ('31341',
#   'Tupac Shakur',
#   175,
#   'BULLET::::- FBI Records: The Vault – Tupac Shakur at FBI.gov\n'),
#  ('180487', 'Steve Buscemi', 43, 'BULLET::::- Steve Buscemi at Emmys.com\n'),
#  ('13149',
#   'Galaxy Quest',
#   88,
#   'BULLET::::- "Three Amigos" – a comedy about actors mistaken for their characters\n'),
#  ('43430636', 'Kris Wu', 37, 'Notes\n'),
#  ('31509', 'Hulk', 81, 'BULLET::::- Hulk on IMDb\n'),
#  ('2396574',
#   'The Formula (1980 film)',
#   47,
#   'BULLET::::- Free energy suppression\n'),
#  ('13275',
#   'Hungary',
#   238,
#   'BULLET::::- Hungary Today – The latest news about Hungary\n'),
#  ('26334893',
#   'PageRank',
#   172,
#   "BULLET::::- How Google Finds Your Needle in the Web's Haystack by the American Mathematical Society\n"),
#  ('854532',
#   'Ron Perlman',
#   20,
#   'On November 9, 2016, Perlman announced via Facebook his intention to run for U.S. President in the 2020 election but dropped out in January 2019, instead endorsing Kamala Harris.\n'),
#  ('247463',
#   'Ryan Phillippe',
#   31,
#   'Phillippe has a black belt in Tae Kwon Do.\n'),
#  ('31586',
#   'Ty Cobb',
#   112,
#   'BULLET::::- Ty Cobb: The Georgia Peach historical marker\n'),
#  ('30987670',
#   'Suits (American TV series)',
#   56,
#   'Yūji Oda and Yuto Nakajima play leading roles in a Japanese remake broadcast by Fuji Television in 2018.\n'),
#  ('13373',
#   'Haiti',
#   332,
#   'BULLET::::- Instituto Dominicano de Desarrollo Integral, the Dominican parent of the Haitian Institute of Integral Development.\n'),
#  ('4908353',
#   'All the Pretty Horses (film)',
#   39,
#   'BULLET::::- Best Supporting Actor - Young Artist Awards (Lucas Black)\n'),
#  ('31717',
#   'United Kingdom',
#   234,
#   'BULLET::::- Official tourist guide to Britain\n'),
#  ('51569009',
#   'Evolution (Sabrina Carpenter album)',
#   52,
#   'BULLET::::- Harper Smith – photography\n'),
#  ('473212',
#   'Alice (1990 film)',
#   47,
#   "Woody Allen received an Academy Award nomination for Best Original Screenplay, as well as a Writers Guild of America nomination. Mia Farrow received a Golden Globe nomination for Best Performance by an Actress in a Motion Picture – Comedy/Musical and won the National Board of Review's Award for Best Actress.\n"),
#  ('2668402',
#   'Leroy Jethro Gibbs',
#   67,
#   "BULLET::::- Mark Harmon's CBS profile\n"),
#  ('316592', 'Brock Lesnar', 163, 'BULLET::::- Hottest Rivalry (2018) –\n'),
#  ('1152227',
#   'Sarah Silverman',
#   50,
#   'BULLET::::- Sarah Silverman Video produced by ""\n'),
#  ('142435',
#   'Jerry Maguire',
#   93,
#   'BULLET::::- Leigh Steinberg (the agent based on Jerry Maguire) talks about Cameron Crowe and the film\n'),
#  ('100730',
#   'Winnipeg',
#   98,
#   'BULLET::::- Winnipeg.ca\xa0– Official city website\n'),
#  ('994552',
#   'Travis Barker',
#   95,
#   'BULLET::::- Cymbal configuration at Zildjian.com\n'),
#  ('46301800',
#   'Stranger Things',
#   106,
#   'BULLET::::- Analysis of the Duffer Brothers\' "show bible" from Screencraft.org\n'),
#  ('29909823', 'Kendrick Lamar', 97, 'BULLET::::- Music of California\n'),
#  ('101393', 'Liev Schreiber', 53, 'BULLET::::- Interview with "W" magazine\n'),
#  ('101401',
#   'Hamlet (1990 film)',
#   37,
#   "BULLET::::- Shooting script available via the University of Birmingham's Virtual Manuscript Room.\n"),
#  ('181774',
#   'Academy Honorary Award',
#   19,
#   'BULLET::::- "The Official Academy Awards Database".\n'),
#  ('46310771',
#   'The Belko Experiment',
#   49,
#   'According to the review aggregator website Rotten Tomatoes, 52% of critics have given the film a positive review based on 98 reviews, with an average rating of 5.51/10. The site\'s critics consensus reads, ""The Belko Experiment" offers a few moments of lurid fun for genre enthusiasts, but lacks enough subversive smarts to consistently engage once the carnage kicks in." On Metacritic, the film has a score 44 out of 100 based on 21 critics, indicating "mixed or average reviews".\n'),
#  ('18617682', 'Mark Hamill', 66, 'BULLET::::- Asteroid 110026 Hamill\n'),
#  ('11018205',
#   'The Narrows (film)',
#   12,
#   'BULLET::::- Official Movie Website\n'),
#  ('1157583',
#   'Anil Kapoor',
#   33,
#   'Anil Kapoor has on rare occasions contributed to the soundtracks of his movies as a singer. One of his first playback songs was the title track of the 1986 Bollywood comedy "Chameli Ki Shaadi". The song was comic in nature and depicted the love story of the titular Chameli and her lover Charandas, played by Kapoor. Chameli was portrayed by Amrita Singh. In the same decade, he was credited on the song "Tere Bina Main Nahin Mere Bina Tu Nahin" for the film "Woh Saat Din". He is also credited on the song "I Love You" from "Hamara Dil Aapke Paas Hai". In 2008, Kapoor provided a rhyme-like-dialogue to introduce his character in Yashraj\'s "Tashan". His theme was titled "Bhaiyaji ka Tashan". His co-stars in the movie also had their introductions incorporated in the soundtrack, which was composed by Vishal-Shekhar. Akshay Kumar\'s theme was titled "Bachchan Pandey ka Tashan". Kareena Kapoor\'s was "Pooja ka Tashan". "Saif Ali Khan" was credited for "Jimmy ka Tashan". He had one full album, "Welcome" as a co-singer with Salma Agha in 1986. The album was scored by Bappi Lahiri.\n'),
#  ('11901160',
#   'The Champ (1979 film)',
#   38,
#   'Produced by Daniel Primer. CBS. The Film Therapy link is available online at The Doctors TV website.\n'),
#  ('1325334',
#   'Jaime Lannister',
#   60,
#   "Coster-Waldau has received several nominations for his portrayal of Jaime, including the Critics' Choice Television Award for Best Supporting Actor in a Drama Series in 2013, the Satellite Award for Best Supporting Actor in a Series, Miniseries or Television Film in 2013, the Gold Derby TV Award for Best Drama Supporting Actor in 2013, the People's Choice Award for Favorite TV Anti-Hero in 2014, the Saturn Award for Best Supporting Actor on Television in 2014, the Zulu Award for Best Actor in 2017, and a Primetime Emmy Award for Outstanding Supporting Actor in a Drama Series in 2018.\n"),
#  ('2675554',
#   'The Smurfs (film)',
#   61,
#   'On May 10, 2012, two weeks after Columbia Pictures and Sony Pictures Animation announced production of "The Smurfs 2", "Variety" reported that writers Karey Kirkpatrick and Chris Poche were developing a script for "The Smurfs 3", which was set for release on July 24, 2015, and later rescheduled for August 14, 2015. In March 2014, Sony announced that it will reboot the series with a completely computer-animated film. Directed by Kelly Asbury, the reboot titled "", was released on April 7, 2017.\n'),
#  ('51604371',
#   'Grace VanderWaal',
#   43,
#   'BULLET::::- VanderWaal\'s "Tiny Desk Concert" at NPR\n'),
#  ('18618306',
#   'Planet of the Apes (1968 film)',
#   82,
#   'BULLET::::- Survival film, about the film genre, with a list of related films\n'),
#  ('47516817', 'Room 93', 7, 'BULLET::::- signifies a co-producer.\n'),
#  ('36524612',
#   'Henry V (2012 film)',
#   39,
#   "Baron's Hall in Penshurst Place was used as the setting for the French Palace and Squerryes Court doubled as the French battle court field.\n"),
#  ('182128',
#   'American Gods',
#   106,
#   'BULLET::::- "Only the gods are real", a listing of all the gods and mythical beings featured in "American Gods"\n'),
#  ('182182', 'Arkham Asylum', 127, 'BULLET::::- Official Videogame Website\n'),
#  ('394493',
#   'Jerry Goldsmith',
#   327,
#   'BULLET::::- Sammy Lifetime Achievement Award\n'),
#  ('13774',
#   'Houston',
#   191,
#   'BULLET::::- Greater Houston Transportation and Emergency Management Center\n'),
#  ('13787',
#   'Hermetic Order of the Golden Dawn',
#   136,
#   'BULLET::::- Hermetic Order of the Golden Dawn: Biographies of Members\n'),
#  ('18620916',
#   'Steven Knight',
#   19,
#   'BULLET::::- The Making of Locke: An Interview with Writer/Director Steve Knight, Part 2 at PostMovie.net\n'),
#  ('18621887',
#   'Ted Kaczynski',
#   120,
#   'BULLET::::- Review Does the Unabomber Have a More Realistic Sense of Today\'s Existential Risks? of "Anti-Tech Revolution: Why and How" by Steve Fuller\n'),
#  ('1535704',
#   'Chris Evans (actor)',
#   26,
#   'After Alabama passed the Human Life Protection Act, which imposes a near-total ban on abortions in the state, Evans wrote on Twitter that the bill was "absolutely unbelievable" and continued by saying, "If you\'re not worried about "Roe v. Wade", you\'re not paying attention."\n'),
#  ('8543614',
#   'Donald Glover',
#   56,
#   'BULLET::::- 2018 Profile of Glover on BBC Radio Four\n'),
#  ('395465',
#   'Brian Helgeland',
#   13,
#   'On May 4, 2017, HBO announced that Helgeland is one of four writers working on a potential pilot for a "Game of Thrones" spin-off. In addition to Helgeland, Carly Wray, Max Borenstein, and Jane Goldman are also working on potential pilots. Helgeland has been working and communicating with George R. R. Martin, the author of "A Song of Ice and Fire", the series of novels upon which the original series is based. Current "Game of Thrones" showrunners D. B. Weiss and David Benioff would also be executive producers for whichever project is picked up by HBO.\n'),
#  ('102690',
#   'Adam Sandler',
#   38,
#   'In 2009 Sandler contributed the Neil Young cover "Like a Hurricane" to "Covered, A Revolution in Sound" as part of Warner Brothers 50th Anniversary celebrations; the song was performed on the "David Letterman Show" with a band that included, among others, Waddy Wachtel, who has appeared with Sandler on a number of occasions.\n'),
#  ('143809',
#   'The Fifth Element',
#   64,
#   'The 20th anniversary 4K remaster was released on Ultra HD Blu-ray on July 11, 2017.\n'),
#  ('143834',
#   'The Boys from Brazil (film)',
#   75,
#   'BULLET::::- Dr. Josef Mengele – Nominated Villain\n'),
#  ('143871',
#   'Cosmopolitan (magazine)',
#   86,
#   'BULLET::::- "Hearst\'s international combined with Cosmopolitan" at the HathiTrust\n'),
#  ('11922721',
#   'Phantoms (film)',
#   34,
#   '"Phantoms" received a 13% rating on Rotten Tomatoes, based on 30 reviews. Roger Ebert gave the film 1 star out of 4, saying "If only we could learn to think more kindly of those who digest us, this movie could have ended happily." The film grossed $5.6 million at the box office.\n')]

# %%
def get_paragraph_batch(index, batch_size = 25):
    return con.execute("SELECT * FROM paragraph LIMIT ? OFFSET ?", [batch_size, index*batch_size]).df()


get_paragraph_batch(1)
# Out:
#    wikipedia_id                   wikipedia_title  paragraph_id  \
# 0      34604303               Quartet (2012 film)            49
# 1       2025815                   Louise Simonson           105
# 2      23882849                  Taylor Schilling            13
# 3       1218644                     Jordan Knight            39
# 4        158889                    George Clooney            69
# 5        209066                     Reba McEntire           117
# 6      22941812                      Furia (film)            11
# 7         75912                         Time Lord           102
# 8         76033                  The Great Gatsby           105
# 9      52281037              Inhumans (TV series)            89
# 10       756494                     Tanya Roberts            20
# 11       422524         National Library of India            35
# 12     21003892                Lee Min-ho (actor)            46
# 13       346200                        Kurt Angle           210
# 14     39383953    In the Heart of the Sea (film)            57
# 15     38242002                        Until Dawn            36
# 16      1219461                J. Howard Marshall            29
# 17       159268                     River Phoenix            66
# 18     37026799                      Unapologetic           171
# 19        76383  The Ten Commandments (1956 film)           128
# 20       625105                       David Koepp            15
# 21       347105                     Mother Teresa           139
# 22     45230258  Beauty and the Beast (2017 film)            78
# 23        44469                             Pluto           112
# 24        44475                            Uranus           105
#
#                                                  text
# 0   Lisa Schwarzbaum of "Entertainment Weekly" gav...
# 1   BULLET::::- Louise Simonson at the Unofficial ...
# 2        BULLET::::- LGBTQ culture in New York City\n
# 3             BULLET::::- Trans Continental Records\n
# 4   Throughout his career, Clooney has won two Aca...
# 5   BULLET::::- Reba McEntire Profile on Country M...
# 6          BULLET::::- Étienne Chicot as Quicailler\n
# 7                 BULLET::::- Time War (Doctor Who)\n
# 8        BULLET::::- An Index to "The Great Gatsby"\n
# 9                    BULLET::::- General references\n
# 10  Roberts was married to husband Barry Roberts f...
# 11            BULLET::::- National Library of India\n
# 12            BULLET::::- Official Japanese website\n
# 13  BULLET::::- Kurt Angle at The National Wrestli...
# 14  BULLET::::- Survival film, about the film genr...
# 15  Sony announced a non-canonical spin-off titled...
# 16  BULLET::::- Again, Hot Oil from Time Magazine,...
# 17  BULLET::::- Holmstrom, John. "The Moving Pictu...
# 18    BULLET::::- Promotional website for the album\n
# 19  BULLET::::- Costume design drawings for "The T...
# 20  Koepp was born in Pewaukee, Wisconsin, to a fa...
# 21             BULLET::::- Mother Teresa contrasts:\n
# 22  On March 21, 2017, Sean Bailey said that Walt ...
# 23  BULLET::::- Interactive 3D visualisation of th...
# 24  BULLET::::- Interactive 3D visualisation of th...
