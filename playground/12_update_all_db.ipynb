# %%
import duckdb

# %%
TARGET_DB = '../data/all.duckdb'

# %%
con = duckdb.connect(TARGET_DB, read_only=True)

# %%
# con.sql("ALTER TABLE paragraph ADD COLUMN has_vec BOOLEAN")

# %%
# con.sql("UPDATE paragraph SET has_vec = vec IS NOT NULL")

# %%
con.execute("SELECT * FROM paragraph WHERE has_vec = TRUE ORDER BY global_id LIMIT 10").df()
# Out:
#   wikipedia_id                           wikipedia_title  global_id  index  \
# 0          290                                         A          1     69
# 1           39                                    Albedo          2     87
# 2          316  Academy Award for Best Production Design          3      6
# 3          330                                   Actrius          4     20
# 4          332                           Animalia (book)          5     18
# 5          309                      An American in Paris          6     30
# 6          334                 International Atomic Time          7     31
# 7          340                              Alain Connes          8     25
# 8          344                                Allan Dwan          9    147
# 9           25                                    Autism         10    109
#
#                                                 text  \
# 0              BULLET::::- History of the Alphabet\n
# 1       BULLET::::- reflectivity of metals (chart)\n
# 2  BULLET::::- Critics' Choice Movie Award for Be...
# 3  BULLET::::- as archived February 17, 2009 (Spa...
# 4  BULLET::::- A Learning Time activity guide for...
# 5  BULLET::::- , New York Philharmonic, Leonard B...
# 6  BULLET::::- Standard of time definition: UTC, ...
# 7  BULLET::::- An interview with Alain Connes and...
# 8  BULLET::::- Allan Dwan profile, virtual-histor...
# 9  About half of autistics are unemployed, and on...
#
#                                                  vec  has_vec
# 0  [0.14550781, -0.021972656, 0.10595703, 0.05664...     True
# 1  [0.029907227, 0.052246094, -0.016113281, -0.03...     True
# 2  [0.06982422, -0.0053100586, 0.041015625, 0.136...     True
# 3  [0.053222656, 0.015319824, -0.049804688, 0.106...     True
# 4  [0.006713867, -0.011779785, 0.171875, 0.109863...     True
# 5  [0.017700195, 0.06591797, -0.08154297, 0.15917...     True
# 6  [0.079589844, -0.006378174, 0.06640625, 0.0319...     True
# 7  [0.12109375, -0.12890625, -0.025512695, 0.0534...     True
# 8  [0.05908203, -0.11425781, 0.01940918, 0.000141...     True
# 9  [-0.010009766, -0.106933594, -0.032714844, 0.0...     True

# %%
con.execute("SELECT count(*) FROM paragraph WHERE has_vec = FALSE").fetchall()[0][0]
# Out:
# 111789797

# %%
con.execute("SELECT * FROM paragraph WHERE vec IS NOT NULL LIMIT 100").df()
