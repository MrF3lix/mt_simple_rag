# %%
import duckdb

# %%
TARGET_DB = '../data/all.duckdb'

# %%
con = duckdb.connect(TARGET_DB, read_only=True)
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 con = duckdb.connect(TARGET_DB, read_only=True)
#
# IOException: IO Error: Could not set lock on file "/cluster/home/saaf/MT/mt_simple_rag/playground/../data/all.duckdb": Conflicting lock is held in PID -1289318. See also https://duckdb.org/docs/stable/connect/concurrency
