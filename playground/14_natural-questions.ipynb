# %%
import pandas as pd
from datasets import load_dataset

# %%
SOURCE = '../data/natural-questions/nq-train-kilt.jsonl.txt'
OUTPUT = '../data/natural-questions/nq-train-kilt_fixed.jsonl'

# %%
def get_references(output):
    references = []

    if len(output) == 0:
        return None
    
    if 'provenance' not in output[0].keys():
        return None

    for p in output[0]['provenance']:
        references.append({
            'document_id': p['wikipedia_id'],
            'index': p['start_paragraph_id'] + 1,
            'global_id': None,
            'text': None
        })

    return references


df = pd.read_json(SOURCE, lines=True)
df.iloc[0]['output']

df['id'] = df['id'].astype(str)
df['answer'] = df['output'].apply(lambda l: l[0]['answer'])
df['references'] = df['output'].apply(get_references)

df.loc[~df['references'].isna()].sample(10).to_json(OUTPUT, lines=True, orient='records')

# %%
def get_references(row):
    references = []
    output = row['output']

    for p in output[0]['provenance']:
        references.append({
            'document_id': p['wikipedia_id'],
            'index': p['start_paragraph_id'] + 1,
            'global_id': None,
            'text': None
        })

    return {
        'id': row['id'],
        'answer': output[0]['answer'],
        'references': references
    }

# %%
kilt_nq = load_dataset("facebook/kilt_tasks", name="nq")
kilt_nq
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'input', 'meta', 'output'],
#         num_rows: 87372
#     })
#     validation: Dataset({
#         features: ['id', 'input', 'meta', 'output'],
#         num_rows: 2837
#     })
#     test: Dataset({
#         features: ['id', 'input', 'meta', 'output'],
#         num_rows: 1444
#     })
# })

# %%
train_clean = kilt_nq['train'].filter(lambda row: (len(row['output'][0]['provenance']) > 0))

subset = train_clean

relevant = subset.map(get_references)
relevant
# Out:
# Map: 100%|██████████| 74038/74038 [00:06<00:00, 10645.83 examples/s]
# Dataset({
#     features: ['id', 'input', 'meta', 'output', 'answer', 'references'],
#     num_rows: 74038
# })

# %%
relevant.select_columns(['id', 'input', 'answer', 'references']).to_pandas()
# Out:
#                          id  \
# 0       5328212470870865242
# 1       5289242154789678439
# 2      -2500044561429484630
# 3      -7491001389340565191
# 4       4706363175863681196
# ...                     ...
# 74033   5088894102963373562
# 74034   2872167102791875297
# 74035  -6443678100256960002
# 74036   7553133436598981958
# 74037  -8683297919344444734
#
#                                                    input  \
# 0                how i.met your mother who is the mother
# 1                       who had the most wins in the nfl
# 2            who played mantis guardians of the galaxy 2
# 3      god's not dead a light in the darkness release...
# 4             when do the eclipse supposed to take place
# ...                                                  ...
# 74033           who plays tupac mother in all eyez on me
# 74034         who has scored more goals messi or ronaldo
# 74035          who made the world's first computer virus
# 74036        when does season 5 of senora acero come out
# 74037                   who said no to this is your life
#
#                               answer  \
# 0                    Tracy McConnell
# 1                          Tom Brady
# 2                    Pom Klementieff
# 3                    March 30 , 2018
# 4                   August 21 , 2017
# ...                              ...
# 74033                   Danai Gurira
# 74034              Cristiano Ronaldo
# 74035              Basit Farooq Alvi
# 74036                15 October 2018
# 74037  Footballer Danny Blanchflower
#
#                                               references
# 0      [{'document_id': '40262098', 'global_id': None...
# 1      [{'document_id': '13929036', 'global_id': None...
# 2      [{'document_id': '43209054', 'global_id': None...
# 3      [{'document_id': '56095752', 'global_id': None...
# 4      [{'document_id': '4762233', 'global_id': None,...
# ...                                                  ...
# 74033  [{'document_id': '48919161', 'global_id': None...
# 74034  [{'document_id': '43992506', 'global_id': None...
# 74035  [{'document_id': '175852', 'global_id': None, ...
# 74036  [{'document_id': '58414668', 'global_id': None...
# 74037  [{'document_id': '11468408', 'global_id': None...
#
# [74038 rows x 4 columns]

# %%
kilt_fever = load_dataset("kilt_tasks", name="fever")
allowed = ['SUPPORTS', 'REFUTES']

train_clean = kilt_fever['train'].filter(lambda row: (row['output'][0]['answer'] in allowed and len(row['output'][0]['provenance']) > 0))

subset = train_clean.select(range(self.cfg.documents.subset_size))
if 'subset_size' in self.cfg.documents.keys():
    subset = train_clean.select(range(self.cfg.documents.subset_size))
else:
    subset = train_clean

relevant = subset.map(self.extract_relevant_references)

relevant.select_columns(['id', 'input', 'answer', 'references']).to_json(self.cfg.documents.target)

return list(map(lambda r: r[0]['document_id'], list(relevant['references'])))
